# %% [markdown]
# ### Martina Crippa - 915326

# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
#
# ## <span style="color:blue">  Numerical exercises 10 - SOLUTION</span>

# %% [markdown]
# All c++ code is stored into exercize_xx/es_10.x/ folder, for every point of exercizes.
# All data are stored into exercize_xx/ex_10.x/ folder.

# %%
#common libs
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 10.1

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
x, y = np.loadtxt("es_10.1/TSP_anneal/circle_distance.dat", usecols=(0,1), delimiter=' ', unpack='True')
plt.title("L for best path")
plt.xlabel("Step")
plt.ylabel("L")
plt.plot(x, y)
plt.grid()

plt.subplot(1,2,2)
x, y = np.loadtxt("es_10.1/TSP_anneal/circle_path.dat", usecols=(0,1), delimiter=' ', unpack='True')
plt.title("Path")
plt.plot(x, y, '-o')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
x, y = np.loadtxt("es_10.1/TSP_anneal/square_distance.dat", usecols=(0,1), delimiter=' ', unpack='True')
plt.title("L for best path")
plt.xlabel("Generation")
plt.ylabel("L")
plt.plot(x, y)
plt.grid()

plt.subplot(1,2,2)
x, y = np.loadtxt("es_10.1/TSP_anneal/square_path.dat", usecols=(0,1), delimiter=' ', unpack='True')
plt.title("Path")
plt.plot(x, y, '-o')

plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see comparing the path above and that of exercize 09, we don't obtain the shortes path for cities inside square from this algorithm, but we can obtain a good path too.

# %% [markdown]
# ### Exercise 10.2
